# %% [markdown]
# <a href="https://colab.research.google.com/github/madhumithadasarathy/COB_DataScience/blob/main/Phase2Task2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Importing necessary libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# #Loading the Dataset

# %%
train_df = pd.read_csv("/content/train-csv - Sheet1.csv")

# %%
test_df = pd.read_csv("/content/Test-csv - Sheet1.csv")

# %% [markdown]
# #Checking for null values

# %%
train_df.isnull().sum()
# Out:
# x    0
# y    1
# dtype: int64

# %%
train_df = train_df.dropna()

# %%
train_df.isnull().sum()
# Out:
# x    0
# y    0
# dtype: int64

# %%
test_df.isnull().sum()
# Out:
# x    0
# y    0
# dtype: int64

# %% [markdown]
# #Splitting the datasets

# %%
X_train = train_df.iloc[:,:-1].values
y_train = train_df.iloc[:,-1].values

# %%
X_test = test_df.iloc[:,:-1].values
y_test = test_df.iloc[:,-1].values

# %%
X_train
# Out:
# array([[ 24.],
#        [ 50.],
#        [ 15.],
#        [ 38.],
#        [ 87.],
#        [ 36.],
#        [ 12.],
#        [ 81.],
#        [ 25.],
#        [  5.],
#        [ 16.],
#        [ 16.],
#        [ 24.],
#        [ 39.],
#        [ 54.],
#        [ 60.],
#        [ 26.],
#        [ 73.],
#        [ 29.],
#        [ 31.],
#        [ 68.],
#        [ 87.],
#        [ 58.],
#        [ 54.],
#        [ 84.],
#        [ 58.],
#        [ 49.],
#        [ 20.],
#        [ 90.],
#        [ 48.],
#        [  4.],
#        [ 25.],
#        [ 42.],
#        [  0.],
#        [ 60.],
#        [ 93.],
#        [ 39.],
#        [  7.],
#        [ 21.],
#        [ 68.],
#        [ 84.],
#        [  0.],
#        [ 58.],
#        [ 19.],
#        [ 36.],
#        [ 19.],
#        [ 59.],
#        [ 51.],
#        [ 19.],
#        [ 33.],
#        [ 85.],
#        [ 44.],
#        [  5.],
#        [ 59.],
#        [ 14.],
#        [  9.],
#        [ 75.],
#        [ 69.],
# ...

# %%
y_train
# Out:
# array([ 21.54945196,  47.46446305,  17.21865634,  36.58639803,
#         87.28898389,  32.46387493,  10.78089683,  80.7633986 ,
#         24.61215147,   6.96331907,  11.23757338,  13.53290206,
#         24.60323899,  39.40049976,  48.43753838,  61.69900319,
#         26.92832418,  70.4052055 ,  29.34092408,  25.30895192,
#         69.02934339,  84.99484703,  57.04310305,  50.5921991 ,
#         83.02772202,  57.05752706,  47.95883341,  24.34226432,
#         94.68488281,  48.03970696,   7.08132338,  21.99239907,
#         42.33151664,   0.32908944,  61.92303698,  91.17716423,
#         39.45358014,   5.99606961,  22.59015942,  61.18044414,
#         85.02778957,  -1.28631089,  61.94273962,  21.96033347,
#         33.66194193,  17.60946242,  58.5630564 ,  52.82390762,
#         22.1363481 ,  35.07467353,  86.18822311,  42.63227697,
#          4.09817744,  61.2229864 ,  17.70677576,  11.85312574,
#         80.23051695,  62.64931741,   9.6168598 ,  20.02797699,
# ...

# %%
X_test
# Out:
# array([[ 77],
#        [ 21],
#        [ 22],
#        [ 20],
#        [ 36],
#        [ 15],
#        [ 62],
#        [ 95],
#        [ 20],
#        [  5],
#        [  4],
#        [ 19],
#        [ 96],
#        [ 62],
#        [ 36],
#        [ 15],
#        [ 65],
#        [ 14],
#        [ 87],
#        [ 69],
#        [ 89],
#        [ 51],
#        [ 89],
#        [ 27],
#        [ 97],
#        [ 58],
#        [ 79],
#        [ 21],
#        [ 93],
#        [ 27],
#        [ 99],
#        [ 31],
#        [ 33],
#        [ 80],
#        [ 28],
#        [ 47],
#        [ 53],
#        [ 69],
#        [ 28],
#        [ 33],
#        [ 91],
#        [ 71],
#        [ 50],
#        [ 76],
#        [  4],
#        [ 37],
#        [ 70],
#        [ 68],
#        [ 40],
#        [ 35],
#        [ 94],
#        [ 88],
#        [ 52],
#        [ 31],
#        [ 59],
#        [  0],
#        [ 39],
#        [ 64],
#        [ 69],
#        [ 57],
#        [ 13],
#        [ 72],
# ...

# %%
y_test
# Out:
# array([ 79.77515201,  23.17727887,  25.60926156,  17.85738813,
#         41.84986439,   9.80523488,  58.87465933,  97.61793701,
#         18.39512747,   8.74674765,   2.81141583,  17.09537241,
#         95.14907176,  61.38800663,  40.24701716,  14.82248589,
#         66.95806869,  16.63507984,  90.65513736,  77.22982636,
#         92.11906278,  46.91387709,  89.82634442,  21.71380347,
#         97.41206981,  57.01631363,  78.31056542,  19.1315097 ,
#         93.03483388,  26.59112396,  97.55155344,  31.43524822,
#         35.12724777,  78.61042432,  33.07112825,  51.69967172,
#         53.62235225,  69.46306072,  27.42497237,  36.34644189,
#         95.06140858,  68.16724757,  50.96155532,  78.04237454,
#          5.60766487,  36.11334779,  67.2352155 ,  65.01324035,
#         38.14753871,  34.31141446,  95.28503937,  87.84749912,
#         54.08170635,  31.93063515,  59.61247085,  -1.04011421,
#         47.49374765,  62.60089773,  70.9146434 ,  56.14834113,
# ...

# %%
y_train = y_train.reshape(len(y_train),1)
y_test = y_test.reshape(len(y_test),1)

# %%
y_train
# Out:
# array([[ 21.54945196],
#        [ 47.46446305],
#        [ 17.21865634],
#        [ 36.58639803],
#        [ 87.28898389],
#        [ 32.46387493],
#        [ 10.78089683],
#        [ 80.7633986 ],
#        [ 24.61215147],
#        [  6.96331907],
#        [ 11.23757338],
#        [ 13.53290206],
#        [ 24.60323899],
#        [ 39.40049976],
#        [ 48.43753838],
#        [ 61.69900319],
#        [ 26.92832418],
#        [ 70.4052055 ],
#        [ 29.34092408],
#        [ 25.30895192],
#        [ 69.02934339],
#        [ 84.99484703],
#        [ 57.04310305],
#        [ 50.5921991 ],
#        [ 83.02772202],
#        [ 57.05752706],
#        [ 47.95883341],
#        [ 24.34226432],
#        [ 94.68488281],
#        [ 48.03970696],
#        [  7.08132338],
#        [ 21.99239907],
#        [ 42.33151664],
#        [  0.32908944],
#        [ 61.92303698],
#        [ 91.17716423],
#        [ 39.45358014],
#        [  5.99606961],
#        [ 22.59015942],
#        [ 61.18044414],
# ...

# %%
y_test
# Out:
# array([[ 79.77515201],
#        [ 23.17727887],
#        [ 25.60926156],
#        [ 17.85738813],
#        [ 41.84986439],
#        [  9.80523488],
#        [ 58.87465933],
#        [ 97.61793701],
#        [ 18.39512747],
#        [  8.74674765],
#        [  2.81141583],
#        [ 17.09537241],
#        [ 95.14907176],
#        [ 61.38800663],
#        [ 40.24701716],
#        [ 14.82248589],
#        [ 66.95806869],
#        [ 16.63507984],
#        [ 90.65513736],
#        [ 77.22982636],
#        [ 92.11906278],
#        [ 46.91387709],
#        [ 89.82634442],
#        [ 21.71380347],
#        [ 97.41206981],
#        [ 57.01631363],
#        [ 78.31056542],
#        [ 19.1315097 ],
#        [ 93.03483388],
#        [ 26.59112396],
#        [ 97.55155344],
#        [ 31.43524822],
#        [ 35.12724777],
#        [ 78.61042432],
#        [ 33.07112825],
#        [ 51.69967172],
#        [ 53.62235225],
#        [ 69.46306072],
#        [ 27.42497237],
#        [ 36.34644189],
# ...

# %% [markdown]
# #Building the Regression Model

# %%
from sklearn.linear_model import LinearRegression
reg = LinearRegression()
reg.fit(X_train,y_train)
# Out:
# LinearRegression()

# %% [markdown]
# #Predicting values

# %%
y_pred_train = reg.predict(X_train)
y_pred_test = reg.predict(X_test)

# %%
y_pred_train
# Out:
# array([[23.9084877 ],
#        [49.92555363],
#        [14.90258026],
#        [37.91767705],
#        [86.94983976],
#        [35.91636428],
#        [11.90061112],
#        [80.94590147],
#        [24.90914408],
#        [ 4.89601644],
#        [15.90323665],
#        [15.90323665],
#        [23.9084877 ],
#        [38.91833343],
#        [53.92817916],
#        [59.93211745],
#        [25.90980046],
#        [72.94065041],
#        [28.91176961],
#        [30.91308237],
#        [67.9373685 ],
#        [86.94983976],
#        [57.93080468],
#        [53.92817916],
#        [83.94787061],
#        [57.93080468],
#        [48.92489725],
#        [19.90586217],
#        [89.9518089 ],
#        [47.92424086],
#        [ 3.89536006],
#        [24.90914408],
#        [41.92030257],
#        [-0.10726546],
#        [59.93211745],
#        [92.95377805],
#        [38.91833343],
#        [ 6.89732921],
#        [20.90651855],
#        [67.9373685 ],
#        [83.94787061],
# ...

# %%
y_pred_test
# Out:
# array([[76.94327594],
#        [20.90651855],
#        [21.90717494],
#        [19.90586217],
#        [35.91636428],
#        [14.90258026],
#        [61.93343021],
#        [94.95509081],
#        [19.90586217],
#        [ 4.89601644],
#        [ 3.89536006],
#        [18.90520579],
#        [95.95574719],
#        [61.93343021],
#        [35.91636428],
#        [14.90258026],
#        [64.93539936],
#        [13.90192388],
#        [86.94983976],
#        [68.93802488],
#        [88.95115252],
#        [50.92621001],
#        [88.95115252],
#        [26.91045685],
#        [96.95640358],
#        [57.93080468],
#        [78.9445887 ],
#        [20.90651855],
#        [92.95377805],
#        [26.91045685],
#        [98.95771634],
#        [30.91308237],
#        [32.91439514],
#        [79.94524508],
#        [27.91111323],
#        [46.92358448],
#        [52.92752277],
#        [68.93802488],
#        [27.91111323],
#        [32.91439514],
#        [90.95246528],
# ...

# %% [markdown]
# #Visualising the results

# %%
plt.scatter(X_train, y_train, color = 'red')
plt.plot(X_train, y_pred_train, color = 'blue')
plt.title('X vs Y (Training set)')
plt.xlabel('X')
plt.ylabel('Y')
plt.show()

# %%
plt.scatter(X_test, y_test, color = 'red')
plt.plot(X_test, y_pred_test, color = 'blue')
plt.title('X vs Y (Test set)')
plt.xlabel('X')
plt.ylabel('Y')
plt.show()

# %% [markdown]
# #R2 Score

# %%
from sklearn.metrics import r2_score
r2_score(y_train,y_pred_train)
# Out:
# 0.9907015319025518

# %%
from sklearn.metrics import r2_score
r2_score(y_test,y_pred_test)
# Out:
# 0.9888014444327563
