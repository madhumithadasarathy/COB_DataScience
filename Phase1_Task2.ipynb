# %% [markdown]
# <a href="https://colab.research.google.com/github/madhumithadasarathy/COB_DataScience/blob/main/Phase1_Task2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Importing Necessary libraries

# %%
import pandas as pd
import numpy as np
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler
from scipy import stats

# %% [markdown]
# #Displaying the first five rows of the dataset

# %%
df = pd.read_csv("/content/dataset - netflix1.csv")
df.head()
# Out:
#   show_id     type                             title         director  \
# 0      s1    Movie              Dick Johnson Is Dead  Kirsten Johnson
# 1      s3  TV Show                         Ganglands  Julien Leclercq
# 2      s6  TV Show                     Midnight Mass    Mike Flanagan
# 3     s14    Movie  Confessions of an Invisible Girl    Bruno Garotti
# 4      s8    Movie                           Sankofa     Haile Gerima
#
#          country date_added  release_year rating  duration  \
# 0  United States  9/25/2021          2020  PG-13    90 min
# 1         France  9/24/2021          2021  TV-MA  1 Season
# 2  United States  9/24/2021          2021  TV-MA  1 Season
# 3         Brazil  9/22/2021          2021  TV-PG    91 min
# 4  United States  9/24/2021          1993  TV-MA   125 min
#
#                                            listed_in
# 0                                      Documentaries
# 1  Crime TV Shows, International TV Shows, TV Act...
# ...

# %% [markdown]
# #Displaying initial information about the dataset.

# %%
print("Initial Dataset Information")
print(df.info())
# Out:
# Initial Dataset Information
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8790 entries, 0 to 8789
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8790 non-null   object
#  1   type          8790 non-null   object
#  2   title         8790 non-null   object
#  3   director      8790 non-null   object
#  4   country       8790 non-null   object
#  5   date_added    8790 non-null   object
#  6   release_year  8790 non-null   int64
#  7   rating        8790 non-null   object
#  8   duration      8790 non-null   object
#  9   listed_in     8790 non-null   object
# dtypes: int64(1), object(9)
# memory usage: 686.8+ KB
# None

# %% [markdown]
# # Checking for null values

# %%
df.isnull().sum()
# Out:
# show_id         0
# type            0
# title           0
# director        0
# country         0
# date_added      0
# release_year    0
# rating          0
# duration        0
# listed_in       0
# dtype: int64

# %% [markdown]
# # Printing the Z score

# %%
z_scores = np.abs((df-df.mean()/df.std()))
print(z_scores)
# Out:
#      country date_added director duration listed_in rating  release_year  \
# 0        NaN        NaN      NaN      NaN       NaN    NaN      1791.776
# 1        NaN        NaN      NaN      NaN       NaN    NaN      1792.776
# 2        NaN        NaN      NaN      NaN       NaN    NaN      1792.776
# 3        NaN        NaN      NaN      NaN       NaN    NaN      1792.776
# 4        NaN        NaN      NaN      NaN       NaN    NaN      1764.776
# ...      ...        ...      ...      ...       ...    ...           ...
# 8785     NaN        NaN      NaN      NaN       NaN    NaN      1787.776
# 8786     NaN        NaN      NaN      NaN       NaN    NaN      1787.776
# 8787     NaN        NaN      NaN      NaN       NaN    NaN      1783.776
# 8788     NaN        NaN      NaN      NaN       NaN    NaN      1787.776
# 8789     NaN        NaN      NaN      NaN       NaN    NaN      1787.776
#
#      show_id title type
# 0        NaN   NaN  NaN
# 1        NaN   NaN  NaN
# ...

# %% [markdown]
# # Describing the cleaned dataset.

# %%
df.describe()
# Out:
#        release_year
# count   8790.000000
# mean    2014.183163
# std        8.825466
# min     1925.000000
# 25%     2013.000000
# 50%     2017.000000
# 75%     2019.000000
# max     2021.000000

# %%
print("Cleaned Dataset")
df.head()
# Out:
# Cleaned Dataset
#   show_id     type                             title         director  \
# 0      s1    Movie              Dick Johnson Is Dead  Kirsten Johnson
# 1      s3  TV Show                         Ganglands  Julien Leclercq
# 2      s6  TV Show                     Midnight Mass    Mike Flanagan
# 3     s14    Movie  Confessions of an Invisible Girl    Bruno Garotti
# 4      s8    Movie                           Sankofa     Haile Gerima
#
#          country date_added  release_year rating  duration  \
# 0  United States  9/25/2021          2020  PG-13    90 min
# 1         France  9/24/2021          2021  TV-MA  1 Season
# 2  United States  9/24/2021          2021  TV-MA  1 Season
# 3         Brazil  9/22/2021          2021  TV-PG    91 min
# 4  United States  9/24/2021          1993  TV-MA   125 min
#
#                                            listed_in
# 0                                      Documentaries
# 1  Crime TV Shows, International TV Shows, TV Act...
# ...
